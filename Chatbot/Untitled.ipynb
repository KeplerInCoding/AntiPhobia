# %%
# !pip install chainlit
# Out:
# ...
#      ---------------------------------------- 0.0/65.2 kB ? eta -:--:--
#      ------------------------------------- -- 61.4/65.2 kB 1.7 MB/s eta 0:00:01
#      ---------------------------------------- 65.2/65.2 kB 1.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/45.7 kB ? eta -:--:--
#      ---------------------------------------- 45.7/45.7 kB 2.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#      ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/58.3 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/58.3 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/58.3 kB ? eta -:--:--
#      -------------------- ----------------- 30.7/58.3 kB 187.9 kB/s eta 0:00:01
# ...

# %%
import chainlit as cl
